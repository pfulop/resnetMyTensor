# %%
import keras
import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %%
sess = tf.Session()

# %%
keras.backend.set_session(sess)

# %%
model = keras.applications.resnet50.ResNet50(include_top=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000)

# %%
model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ...
# input_1 (InputLayer)             (None, 224, 224, 3)   0
# ____________________________________________________________________________________________________
# conv1 (Conv2D)                   (None, 112, 112, 64)  9472        input_1[0][0]
# ____________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)    (None, 112, 112, 64)  256         conv1[0][0]
# ____________________________________________________________________________________________________
# activation_1 (Activation)        (None, 112, 112, 64)  0           bn_conv1[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)   (None, 55, 55, 64)    0           activation_1[0][0]
# ...

# %%
from Inputs import Inputs

# %%
import prep

# %%
train_images, train_labels, valid_images, valid_labels, n_classes = prep.prepare_data('/Users/fulop/Downloads/dogbreed/sample/')

# %%
train_inputs = Inputs(train_images, train_labels, n_classes, shuffle = True)

# %%
iterator = train_inputs.generate_iterator()

# %%
model.add(Dense(n_classes, activation='softmax'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-e7bc04da589d> in <module>()
# ----> 1 model.add(Dense(n_classes, activation='softmax'))
#
# AttributeError: 'Model' object has no attribute 'add'

# %%
model.fit(trn, trn_labels, batch_size=10, nb_epoch=3)

# %% [markdown]
# https://blog.keras.io/keras-as-a-simplified-interface-to-tensorflow-tutorial.html
# https://medium.com/implodinggradients/tensorflow-or-keras-which-one-should-i-learn-5dd7fa3f9ca0
# https://github.com/fchollet/keras/issues/5050
# https://github.com/fchollet/keras/issues/3557
